# %%
# !git clone https://kekayan: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@github.com/kekayan/progNet-SAINT.git
# Out:
# Cloning into 'progNet-SAINT'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 78 (delta 36), reused 58 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 971.48 KiB | 8.16 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# %cd progNet-SAINT/src/
# %mkdir output
# Out:
# /content/progNet-SAINT/src
# mkdir: cannot create directory ‘output’: File exists

# %%
import numpy as np
import pandas as pd

import torch
from torch import nn


import torch.optim as optim
from utils import count_parameters, classification_scores, mean_sq_error
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import Dataset, DataLoader


from models import SAINT
from augmentations import embed_data_mask
from augmentations import add_noise
from pretraining import SAINT_pretrain

# %%
df = pd.read_csv("../data/clinical_and_other_features.csv")
df2 = pd.read_csv('../data/clinical_and_other_features_filtered.csv')

# %%
df= df[df["Overall Near-complete Response:  Stricter Definition"].isna()]
df.reset_index(inplace=True, drop=True)
print(df.shape, df2.shape)
# Out:
# (610, 84) (312, 84)

# %%
opt_dict = {
    'd_task': 'clf',
    'dtask': 'clf',
    'task': 'multiclass',
    'batchsize': 32,
    'pt_aug': ['mixup', 'cutmix'],
    'pt_aug_lam': 0.1,
    'pretrain_epochs': 250, #50
    'nce_temp': 0.7,
    'lam0': 0.5,
    'lam1': 10,
    'lam2': 1,
    'lam3': 10,
    'pt_projhead_style': 'diff',
    'pt_tasks': ['contrastive','denoising'],
    'mixup_lam': 0.3,
    'ssl_samples': 312,
    'lr':0.0001,
    'train_noise_type':"missing",
    'train_noise_level':0.3,
    'save_path':"./output/model.pt"
}

class AttributeDict(dict):
    __getattr__ = dict.__getitem__
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

opt = AttributeDict(opt_dict)

# %%
def data_split(X,y,nan_mask,indices):
    x_d = {
        'data': X.values[indices],
        'mask': nan_mask.values[indices]
    }

    if x_d['data'].shape != x_d['mask'].shape:
        raise'Shape of data not same as that of nan mask!'

    y_d = {
        'data': y[indices].reshape(-1, 1)
    }
    return x_d, y_d

# %%
class DataSetCatCon(Dataset):
    def __init__(self, X, Y, cat_cols,task='clf',continuous_mean_std=None):

        cat_cols = list(cat_cols)
        X_mask =  X['mask'].copy()
        X = X['data'].copy()
        con_cols = list(set(np.arange(X.shape[1])) - set(cat_cols))
        self.X1 = X[:,cat_cols].copy().astype(np.int64) #categorical columns
        self.X2 = X[:,con_cols].copy().astype(np.float32) #numerical columns
        self.X1_mask = X_mask[:,cat_cols].copy().astype(np.int64) #categorical columns
        self.X2_mask = X_mask[:,con_cols].copy().astype(np.int64) #numerical columns
        self.y = Y['data']#.astype(np.float32) if regression
        self.cls = np.zeros_like(self.y,dtype=int)
        self.cls_mask = np.ones_like(self.y,dtype=int)
        if continuous_mean_std is not None:
            mean, std = continuous_mean_std
            self.X2 = (self.X2 - mean) / std

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        # X1 has categorical data, X2 has continuous
        return np.concatenate((self.cls[idx], self.X1[idx])), self.X2[idx],self.y[idx], np.concatenate((self.cls_mask[idx], self.X1_mask[idx])), self.X2_mask[idx]

# %%
def prepare_dataset(df,p=[.65, .15, .2]):
  df1 = df.drop(['Overall Near-complete Response:  Looser Definition','Near-complete Response (Graded Measure)'],axis=1)
  df1.columns = df1.columns.str.strip()
  pathologic_response_to_neoadjuvant_therapy = ['Pathologic response to Neoadjuvant therapy: Pathologic stage (T) following neoadjuvant therapy',
        'Pathologic response to Neoadjuvant therapy:  Pathologic stage (N) following neoadjuvant therapy',
        'Pathologic response to Neoadjuvant therapy:  Pathologic stage (M) following neoadjuvant therapy']
  # df1.drop(pathologic_response_to_neoadjuvant_therapy, axis=1, inplace=True)
  X = df1.drop('Overall Near-complete Response:  Stricter Definition',axis=1)
  y = df1['Overall Near-complete Response:  Stricter Definition']
  cont_columns = ['Date of Birth (Days)', 'Days to Surgery (from the date of diagnosis)', 'Age at last contact in EMR f/u(days)(from the date of diagnosis) ,last time patient known to be alive, unless age of death is reported(in such case the age of death',
    'Age at mammo (days)', 'Days to distant recurrence(from the date of diagnosis)', 'Days to local recurrence (from the date of diagnosis)',
    'Days to death (from the date of diagnosis)', 'Days to last local recurrence free assessment (from the date of diagnosis)',
    ]
  categorical_columns = list(set(X.columns) - set(cont_columns))

  # convert categorical columns to str type
  X[categorical_columns] = X[categorical_columns].astype(str)

  cat_idxs = [X.columns.get_loc(c) for c in categorical_columns]
  con_idxs = [X.columns.get_loc(c) for c in cont_columns]
  X["Set"] = np.random.choice(["train", "valid", "test"], p = [.65, .15, .2], size=(X.shape[0],))

  train_indices = X[X.Set=="train"].index
  valid_indices = X[X.Set=="valid"].index
  test_indices = X[X.Set=="test"].index

  X = X.drop(columns=['Set'])
  temp = X.fillna("MissingValue")
#   creates a bert style mask for the missing values
  nan_mask = temp.ne("MissingValue").astype(int)

  cat_dims = []
  for col in categorical_columns:
      X[col] = X[col].fillna("MissingValue")
      l_enc = LabelEncoder()
      X[col] = l_enc.fit_transform(X[col].values)
      cat_dims.append(len(l_enc.classes_))

  for col in cont_columns:
      X[col] = pd.to_numeric(X[col], errors='coerce')
      X.fillna(X.loc[train_indices, col].mean(), inplace=True)
  y = y.values
  l_enc = LabelEncoder()
  y = l_enc.fit_transform(y)
  X_train, y_train = data_split(X,y,nan_mask,train_indices)
  X_valid, y_valid = data_split(X,y,nan_mask,valid_indices)
  X_test, y_test = data_split(X,y,nan_mask,test_indices)
  train_mean, train_std = np.array(X_train['data'][:,con_idxs],dtype=np.float32).mean(0), np.array(X_train['data'][:,con_idxs],dtype=np.float32).std(0)
  train_std = np.where(train_std < 1e-6, 1e-6, train_std)
  continuous_mean_std = np.array([train_mean,train_std]).astype(np.float32)
  train_ds = DataSetCatCon(X_train, y_train, cat_idxs,'clf',continuous_mean_std)
  trainloader = DataLoader(train_ds, batch_size=64, shuffle=True,num_workers=1)

  valid_ds = DataSetCatCon(X_valid, y_valid, cat_idxs,'clf', continuous_mean_std)
  validloader = DataLoader(valid_ds, batch_size=64, shuffle=False,num_workers=1)

  test_ds = DataSetCatCon(X_test, y_test, cat_idxs,'clf', continuous_mean_std)
  testloader = DataLoader(test_ds, batch_size=64, shuffle=False,num_workers=1)
  y_dim = len(np.unique(y_train['data'][:,0]))
  print('Number of classes in train:',y_dim)
  # in test
  print('Number of classes in test:',len(np.unique(y_test['data'][:,0]))
  )
  #in valid
  print('Number of classes in valid:',len(np.unique(y_valid['data'][:,0]))
  )


  cat_dims = np.append(np.array([1]),np.array(cat_dims)).astype(int) #Appending 1 for CLS token, this is later used to generate embeddings.

  return trainloader, validloader, testloader, cat_dims, con_idxs , cat_idxs, y_dim , continuous_mean_std , X_train, y_train, X_valid, y_valid, X_test, y_test, train_ds, valid_ds

# %%
trainloader, validloader, testloader, cat_dims, con_idxs , cat_idxs, y_dim , continuous_mean_std, X_train, y_train, X_valid, y_valid, X_test, y_test, train_ds, valid_ds = prepare_dataset(df,[.8, .2, 0])
# Out:
# Number of classes in train: 1
# Number of classes in test: 1
# Number of classes in valid: 1

# %%
y_dim = 4 # ssl will have unlabelled data

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
criterion = nn.CrossEntropyLoss().to(device)

# %%
model = SAINT(
categories = tuple(cat_dims),
num_continuous = len(con_idxs),
dim = 64,              # embedding dimension
dim_out = 1,
depth = 1,             # depth of the network (nr. of transformer blocks)
heads = 8,             # number of attention heads 8
attn_dropout = 0.1,
ff_dropout = 0.8,
mlp_hidden_mults = (4, 2),
cont_embeddings = 'MLP', # options: 'MLP', 'linear', 'hybrid' (MLP with continuous embeddings concatenated to the transformer block outputs)
attentiontype = 'colrow', # options: 'col', 'row', 'colrow', 'colrowv2'
final_mlp_style = 'sep',
y_dim = y_dim
)
model.to(device)
# Out:
# SAINT(
#   (norm): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#   (simple_MLP): ModuleList(
#     (0-7): 8 x simple_MLP(
#       (layers): Sequential(
#         (0): Linear(in_features=1, out_features=100, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=100, out_features=64, bias=True)
#       )
#     )
#   )
#   (transformer): RowColTransformer(
#     (embeds): Embedding(1108, 64)
#     (layers): ModuleList(
#       (0): ModuleList(
#         (0): PreNorm(
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           (fn): Residual(
#             (fn): Attention(
#               (to_qkv): Linear(in_features=64, out_features=384, bias=False)
#               (to_out): Linear(in_features=128, out_features=64, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1): PreNorm(
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           (fn): Residual(
#             (fn): FeedForward(
#               (net): Sequential(
#                 (0): Linear(in_features=64, out_features=512, bias=True)
#                 (1): GEGLU()
#                 (2): Dropout(p=0.8, inplace=False)
#                 (3): Linear(in_features=256, out_features=64, bias=True)
#               )
#             )
#           )
#         )
#         (2): PreNorm(
#           (norm): LayerNorm((5248,), eps=1e-05, elementwise_affine=True)
#           (fn): Residual(
#             (fn): Attention(
#               (to_qkv): Linear(in_features=5248, out_features=1536, bias=False)
#               (to_out): Linear(in_features=512, out_features=5248, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (3): PreNorm(
#           (norm): LayerNorm((5248,), eps=1e-05, elementwise_affine=True)
#           (fn): Residual(
#             (fn): FeedForward(
#               (net): Sequential(
#                 (0): Linear(in_features=5248, out_features=41984, bias=True)
#                 (1): GEGLU()
#                 (2): Dropout(p=0.8, inplace=False)
#                 (3): Linear(in_features=20992, out_features=5248, bias=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (mask_embed): Embedding(82, 64)
#   )
#   (mlp): MLP(
#     (mlp): Sequential(
#       (0): Linear(in_features=5248, out_features=2624, bias=True)
#       (1): Linear(in_features=2624, out_features=1312, bias=True)
#       (2): Linear(in_features=1312, out_features=1, bias=True)
#     )
#   )
#   (embeds): Embedding(1108, 64)
#   (mask_embeds_cat): Embedding(148, 64)
#   (mask_embeds_cont): Embedding(16, 64)
#   (single_mask): Embedding(2, 64)
#   (pos_encodings): Embedding(82, 64)
#   (mlp1): sep_MLP(
#     (layers): ModuleList(
#       (0): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=1, bias=True)
#         )
#       )
#       (1-2): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (3): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (4): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=6, bias=True)
#         )
#       )
#       (5): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (6): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=35, bias=True)
#         )
#       )
#       (7-9): 3 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (10): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=6, bias=True)
#         )
#       )
#       (11-12): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (13): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=7, bias=True)
#         )
#       )
#       (14-15): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (16): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (17): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=1, bias=True)
#         )
#       )
#       (18): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (19): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (20): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=35, bias=True)
#         )
#       )
#       (21-22): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (23): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (24): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (25-26): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (27): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (28): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=21, bias=True)
#         )
#       )
#       (29): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (30): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=12, bias=True)
#         )
#       )
#       (31): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (32): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=7, bias=True)
#         )
#       )
#       (33): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=21, bias=True)
#         )
#       )
#       (34): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=6, bias=True)
#         )
#       )
#       (35): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (36): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (37): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (38): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (39): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (40): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=6, bias=True)
#         )
#       )
#       (41): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (42-43): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (44): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (45): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=42, bias=True)
#         )
#       )
#       (46): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=11, bias=True)
#         )
#       )
#       (47): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=1, bias=True)
#         )
#       )
#       (48): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=5, bias=True)
#         )
#       )
#       (49): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (50): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=8, bias=True)
#         )
#       )
#       (51): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (52): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (53): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=12, bias=True)
#         )
#       )
#       (54): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (55): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=11, bias=True)
#         )
#       )
#       (56): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=7, bias=True)
#         )
#       )
#       (57): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (58): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=6, bias=True)
#         )
#       )
#       (59-60): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=1, bias=True)
#         )
#       )
#       (61): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (62-63): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (64): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=513, bias=True)
#         )
#       )
#       (65): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=5, bias=True)
#         )
#       )
#       (66): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (67): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=5, bias=True)
#         )
#       )
#       (68): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (69): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=5, bias=True)
#         )
#       )
#       (70): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=1, bias=True)
#         )
#       )
#       (71): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (72): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=186, bias=True)
#         )
#       )
#       (73): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#     )
#   )
#   (mlp2): sep_MLP(
#     (layers): ModuleList(
#       (0-7): 8 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=1, bias=True)
#         )
#       )
#     )
#   )
#   (mlpfory): simple_MLP(
#     (layers): Sequential(
#       (0): Linear(in_features=64, out_features=1000, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=1000, out_features=4, bias=True)
#     )
#   )
#   (pt_mlp): simple_MLP(
#     (layers): Sequential(
#       (0): Linear(in_features=5248, out_features=6297, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=6297, out_features=2624, bias=True)
#     )
#   )
#   (pt_mlp2): simple_MLP(
#     (layers): Sequential(
#       (0): Linear(in_features=5248, out_features=6297, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=6297, out_features=2624, bias=True)
#     )
#   )
# )

# %%
model = SAINT_pretrain(model,train_ds, valid_ds , opt, device=device)
# Out:
# Pretraining begins!
# Model Checkpoint Saved!
# Epoch: 0, Running Loss: 172655.7021484375 , Val Loss: 10552.115234375
# Early Stopping Counter:  1
# Epoch: 1, Running Loss: 157343.81103515625 , Val Loss: 13212.927734375
# Model Checkpoint Saved!
# Epoch: 2, Running Loss: 147862.611328125 , Val Loss: 9488.12109375
# Model Checkpoint Saved!
# Epoch: 3, Running Loss: 118935.58862304688 , Val Loss: 8743.982421875
# Model Checkpoint Saved!
# Epoch: 4, Running Loss: 73798.60559082031 , Val Loss: 2338.560791015625
# Early Stopping Counter:  1
# Epoch: 5, Running Loss: 73377.20483398438 , Val Loss: 6915.70556640625
# Early Stopping Counter:  2
# Epoch: 6, Running Loss: 80101.65258789062 , Val Loss: 4413.203125
# Early Stopping Counter:  3
# Epoch: 7, Running Loss: 60870.944580078125 , Val Loss: 4389.3388671875
# Early Stopping Counter:  4
# Epoch: 8, Running Loss: 64221.003662109375 , Val Loss: 2530.5146484375
# Model Checkpoint Saved!
# Epoch: 9, Running Loss: 47011.30236816406 , Val Loss: 726.5587768554688
# Early Stopping Counter:  1
# Epoch: 10, Running Loss: 41457.91436767578 , Val Loss: 1476.5728759765625
# Model Checkpoint Saved!
# Epoch: 11, Running Loss: 26083.014892578125 , Val Loss: 215.86480712890625
# Early Stopping Counter:  1
# Epoch: 12, Running Loss: 23606.511505126953 , Val Loss: 616.1044311523438
# Early Stopping Counter:  2
# Epoch: 13, Running Loss: 20333.779205322266 , Val Loss: 374.1595458984375
# Early Stopping Counter:  3
# Epoch: 14, Running Loss: 24252.76971435547 , Val Loss: 615.4281616210938
# Early Stopping Counter:  4
# Epoch: 15, Running Loss: 29691.8837890625 , Val Loss: 1043.998046875
# Early Stopping Counter:  5
# Epoch: 16, Running Loss: 26877.001007080078 , Val Loss: 998.783447265625
# Early Stopping Counter:  6
# Epoch: 17, Running Loss: 26057.590362548828 , Val Loss: 1339.504150390625
# Early Stopping Counter:  7
# Epoch: 18, Running Loss: 23413.55288696289 , Val Loss: 405.7862243652344
# Early Stopping Counter:  8
# Epoch: 19, Running Loss: 21338.73159790039 , Val Loss: 467.5452880859375
# Early Stopping Counter:  9
# Epoch: 20, Running Loss: 23908.00701904297 , Val Loss: 2708.181396484375
# Early Stopping Counter:  10
# Epoch: 21, Running Loss: 19889.862670898438 , Val Loss: 376.81903076171875
# Early Stopping Counter:  11
# Early Stopping!
# END OF PRETRAINING!

# %%
# Labelled Data

# %%
trainloader, validloader, testloader, cat_dims, con_idxs , cat_idxs, y_dim , continuous_mean_std, X_train, y_train, X_valid, y_valid, X_test, y_test,_,_ = prepare_dataset(df2)
# Out:
# Number of classes in train: 4
# Number of classes in test: 4
# Number of classes in valid: 4

# %%
optimizer = optim.AdamW(model.parameters(),lr=0.0001, betas=(0.9,0.999))

# %%
modelsave_path='outputs'

# %%
print('We are in semi-supervised learning case')

train_bsize = min(opt.ssl_samples//4,opt.batchsize)
# Out:
# We are in semi-supervised learning case

# %%
train_ds = DataSetCatCon(X_train, y_train, cat_idxs,opt.dtask,continuous_mean_std)
trainloader = DataLoader(train_ds, batch_size=train_bsize, shuffle=True,num_workers=2)

# %% [markdown]
# ## Fine-tuning the pretrained

# %%
# Start K-Fold Cross Validation
# Define the number of splits
n_splits = 4
best_valid_auroc = 0
best_valid_accuracy = 0
best_test_auroc = 0
best_test_accuracy = 0
best_valid_rmse = 100000

early_stop_counter = 0
early_stop_patience = 20

# fold_dict = {}

# Define the KFold object
kf = KFold(n_splits=n_splits, shuffle=True, random_state=21)

# Initialize lists to store the train and validation indices for each fold
train_indices_list = []
valid_indices_list = []

# Loop over the splits and get the train and validation indices for each fold
for train_indices, valid_indices in kf.split(X_train['data']):
    train_indices_list.append(train_indices)
    valid_indices_list.append(valid_indices)
best_test_accuracy_list = []
# Loop over the folds and train the model on each fold
for fold in range(n_splits):
    # Get the train and validation indices for this fold
    train_indices = train_indices_list[fold]
    valid_indices = valid_indices_list[fold]

    # Create the train and validation datasets and dataloaders for this fold
    train_ds = DataSetCatCon(X_train, y_train, cat_idxs,opt.dtask,continuous_mean_std)
    trainloader = DataLoader(train_ds, batch_size=train_bsize,num_workers=2, sampler=torch.utils.data.SubsetRandomSampler(train_indices))
    valid_ds = DataSetCatCon(X_train, y_train, cat_idxs,opt.dtask,continuous_mean_std)
    validloader = DataLoader(valid_ds, batch_size=train_bsize, shuffle=False,num_workers=2, sampler=torch.utils.data.SubsetRandomSampler(valid_indices))
    print(f'Training begins now for # {fold} Fold.')
    # Train the model on this fold
    for epoch in range(300):
        model.train()
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            for j in range(len(data)):
                print(f"Data[{j}] shape: {data[j].shape}, dtype: {data[j].dtype}")
            optimizer.zero_grad()
            # x_categ is the the categorical data, with y appended as last feature. x_cont has continuous data. cat_mask is an array of ones same shape as x_categ except for last column(corresponding to y's) set to 0s. con_mask is an array of ones same shape as x_cont.
            x_categ, x_cont, y_gts, cat_mask, con_mask = data[0].to(device), data[1].to(device),data[2].to(device),data[3].to(device),data[4].to(device)
            if opt.train_noise_type is not None and opt.train_noise_level>0:
                noise_dict = {
                    'noise_type' : opt.train_noise_type,
                    'lambda' : opt.train_noise_level
                }
                if opt.train_noise_type == 'cutmix':
                    x_categ, x_cont = add_noise(x_categ,x_cont, noise_params = noise_dict)
                elif opt.train_noise_type == 'missing':
                    cat_mask, con_mask = add_noise(cat_mask, con_mask, noise_params = noise_dict)
            # We are converting the data to embeddings in the next step

            _ , x_categ_enc, x_cont_enc = embed_data_mask(x_categ, x_cont, cat_mask, con_mask,model)
            reps = model.transformer(x_categ_enc, x_cont_enc)
            # select only the representations corresponding to y and apply mlp on it in the next step to get the predictions.
            y_reps = reps[:,0,:]

            y_outs = model.mlpfory(y_reps)
            if opt.task == 'regression':
                loss = criterion(y_outs,y_gts)
            else:
                loss = criterion(y_outs,y_gts.squeeze())
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
        print(running_loss)
        if epoch%5==0:
            model.eval()
            with torch.no_grad():
                if opt.task in ['binary','multiclass']:
                    accuracy, auroc = classification_scores(model, validloader, device, opt.task)
                    # test_accuracy, test_auroc = classification_scores(model, testloader, device, opt.task)

                    print('[EPOCH %d] VALID ACCURACY: %.3f' %
                        (epoch + 1, accuracy ))
                    # print('[EPOCH %d] TEST ACCURACY: %.3f' %
                    #     (epoch + 1, test_accuracy ))

            if opt.task =='multiclass':
                if accuracy > best_valid_accuracy:
                    best_valid_accuracy = accuracy
                    early_stop_counter = 0
                    print("save model")
                    torch.save({'model': model, 'state_dict': model.state_dict(),'optimizer' : optimizer.state_dict()},modelsave_path+f"model-{fold}.pt")
                else:
                  early_stop_counter +=1
                  if early_stop_counter > early_stop_patience:
                    break

    model.eval()
    with torch.no_grad():
            accuracy, auroc = classification_scores(model, testloader, device, opt.task)
            print('TEST ACCURACY: %.3f' % accuracy)
            best_test_accuracy_list.append(accuracy)



# End K Fold
# Calculate the average of the best accuracy from each fold
average_best_valid_accuracy = sum(best_test_accuracy_list) / len(best_test_accuracy_list)
print('Average best validation accuracy from all folds:', average_best_valid_accuracy)
# Out:
# Streaming output truncated to the last 5000 lines.
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 1.1003119349479675
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 1.2183144502341747
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 1.4353340864181519
# [EPOCH 71] VALID ACCURACY: 84.000
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.796677328646183
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.7606269791722298
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 1.0706161484122276
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.8706969227641821
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.7053345814347267
# [EPOCH 76] VALID ACCURACY: 66.000
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.6387499123811722
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 1.0704072564840317
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.6679425910115242
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.7690153494477272
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.5837020799517632
# [EPOCH 81] VALID ACCURACY: 80.000
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.6969172060489655
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.3643688661977649
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.5904032494872808
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.45710624009370804
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.6822229251265526
# [EPOCH 86] VALID ACCURACY: 80.000
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 1.4112814962863922
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.9819431379437447
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.804580807685852
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.6947060413658619
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.22321594692766666
# [EPOCH 91] VALID ACCURACY: 78.000
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.7403155900537968
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.9564336203038692
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 2.1230074763298035
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.6479300297796726
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.8205841667950153
# [EPOCH 96] VALID ACCURACY: 82.000
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.48592932894825935
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.5850128792226315
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 1.0297392159700394
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.5495893638581038
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.6090259589254856
# [EPOCH 101] VALID ACCURACY: 82.000
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.46348932944238186
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# ...
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.49215469136834145
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.44671419146470726
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.47441800381056964
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.8866179862525314
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.27095464430749416
# [EPOCH 101] VALID ACCURACY: 100.000
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.8579593375325203
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.1878108037635684
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.6325001809746027
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.42620906978845596
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([20, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([20, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([20, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([20, 8]), dtype: torch.int64
# 0.626112088561058
# [EPOCH 106] VALID ACCURACY: 98.000
# TEST ACCURACY: 86.364
# Training begins now for # 2 Fold.
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([21, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([21, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([21, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([21, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([21, 8]), dtype: torch.int64
# 1.0688180923461914
# [EPOCH 1] VALID ACCURACY: 100.000
# TEST ACCURACY: 87.879
# Training begins now for # 3 Fold.
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([32, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([32, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([32, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([32, 8]), dtype: torch.int64
# Data[0] shape: torch.Size([21, 74]), dtype: torch.int64
# Data[1] shape: torch.Size([21, 8]), dtype: torch.float32
# Data[2] shape: torch.Size([21, 1]), dtype: torch.int64
# Data[3] shape: torch.Size([21, 74]), dtype: torch.int64
# Data[4] shape: torch.Size([21, 8]), dtype: torch.int64
# 0.8256996870040894
# [EPOCH 1] VALID ACCURACY: 100.000
# TEST ACCURACY: 89.394
# Average best validation accuracy from all folds: 88.63636589050293

# %%
best_test_accuracy_list
# Out:
# [array(90.909096, dtype=float32),
#  array(86.36364, dtype=float32),
#  array(87.878784, dtype=float32),
#  array(89.39394, dtype=float32)]

# %% [markdown]
# ## Supervised Training

# %%
model = SAINT(
categories = tuple(cat_dims),
num_continuous = len(con_idxs),
dim = 64,              # embedding dimension
dim_out = 1,
depth = 1,             # depth of the network (nr. of transformer blocks)
heads = 8,             # number of attention heads 8
attn_dropout = 0.1,
ff_dropout = 0.8,
mlp_hidden_mults = (4, 2),
cont_embeddings = 'MLP', # options: 'MLP', 'linear', 'hybrid' (MLP with continuous embeddings concatenated to the transformer block outputs)
attentiontype = 'colrow', # options: 'col', 'row', 'colrow', 'colrowv2'
final_mlp_style = 'sep',
y_dim = y_dim
)
model.to(device)
# Out:
# SAINT(
#   (norm): LayerNorm((8,), eps=1e-05, elementwise_affine=True)
#   (simple_MLP): ModuleList(
#     (0-7): 8 x simple_MLP(
#       (layers): Sequential(
#         (0): Linear(in_features=1, out_features=100, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=100, out_features=64, bias=True)
#       )
#     )
#   )
#   (transformer): RowColTransformer(
#     (embeds): Embedding(828, 64)
#     (layers): ModuleList(
#       (0): ModuleList(
#         (0): PreNorm(
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           (fn): Residual(
#             (fn): Attention(
#               (to_qkv): Linear(in_features=64, out_features=384, bias=False)
#               (to_out): Linear(in_features=128, out_features=64, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1): PreNorm(
#           (norm): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#           (fn): Residual(
#             (fn): FeedForward(
#               (net): Sequential(
#                 (0): Linear(in_features=64, out_features=512, bias=True)
#                 (1): GEGLU()
#                 (2): Dropout(p=0.8, inplace=False)
#                 (3): Linear(in_features=256, out_features=64, bias=True)
#               )
#             )
#           )
#         )
#         (2): PreNorm(
#           (norm): LayerNorm((5248,), eps=1e-05, elementwise_affine=True)
#           (fn): Residual(
#             (fn): Attention(
#               (to_qkv): Linear(in_features=5248, out_features=1536, bias=False)
#               (to_out): Linear(in_features=512, out_features=5248, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (3): PreNorm(
#           (norm): LayerNorm((5248,), eps=1e-05, elementwise_affine=True)
#           (fn): Residual(
#             (fn): FeedForward(
#               (net): Sequential(
#                 (0): Linear(in_features=5248, out_features=41984, bias=True)
#                 (1): GEGLU()
#                 (2): Dropout(p=0.8, inplace=False)
#                 (3): Linear(in_features=20992, out_features=5248, bias=True)
#               )
#             )
#           )
#         )
#       )
#     )
#     (mask_embed): Embedding(82, 64)
#   )
#   (mlp): MLP(
#     (mlp): Sequential(
#       (0): Linear(in_features=5248, out_features=2624, bias=True)
#       (1): Linear(in_features=2624, out_features=1312, bias=True)
#       (2): Linear(in_features=1312, out_features=1, bias=True)
#     )
#   )
#   (embeds): Embedding(828, 64)
#   (mask_embeds_cat): Embedding(148, 64)
#   (mask_embeds_cont): Embedding(16, 64)
#   (single_mask): Embedding(2, 64)
#   (pos_encodings): Embedding(82, 64)
#   (mlp1): sep_MLP(
#     (layers): ModuleList(
#       (0): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=1, bias=True)
#         )
#       )
#       (1): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (2): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=1, bias=True)
#         )
#       )
#       (3): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (4): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (5): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (6): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=40, bias=True)
#         )
#       )
#       (7-9): 3 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (10): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=7, bias=True)
#         )
#       )
#       (11): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (12): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (13): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=9, bias=True)
#         )
#       )
#       (14-15): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (16-18): 3 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (19): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (20): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=40, bias=True)
#         )
#       )
#       (21-22): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (23): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (24): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (25): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (26): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (27): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (28): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=27, bias=True)
#         )
#       )
#       (29): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (30): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=11, bias=True)
#         )
#       )
#       (31): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (32): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=9, bias=True)
#         )
#       )
#       (33): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=27, bias=True)
#         )
#       )
#       (34): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=6, bias=True)
#         )
#       )
#       (35): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (36-37): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (38): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (39): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (40): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=6, bias=True)
#         )
#       )
#       (41): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (42-43): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (44): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (45): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=27, bias=True)
#         )
#       )
#       (46): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=12, bias=True)
#         )
#       )
#       (47): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=8, bias=True)
#         )
#       )
#       (48): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=5, bias=True)
#         )
#       )
#       (49): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (50): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=9, bias=True)
#         )
#       )
#       (51): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (52): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (53): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=11, bias=True)
#         )
#       )
#       (54): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (55): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=12, bias=True)
#         )
#       )
#       (56): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (57): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (58-59): 2 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=5, bias=True)
#         )
#       )
#       (60): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=6, bias=True)
#         )
#       )
#       (61): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=4, bias=True)
#         )
#       )
#       (62): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (63): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=1, bias=True)
#         )
#       )
#       (64): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=275, bias=True)
#         )
#       )
#       (65): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=5, bias=True)
#         )
#       )
#       (66): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (67): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=5, bias=True)
#         )
#       )
#       (68): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (69): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=5, bias=True)
#         )
#       )
#       (70): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#       (71): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=2, bias=True)
#         )
#       )
#       (72): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=115, bias=True)
#         )
#       )
#       (73): simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=3, bias=True)
#         )
#       )
#     )
#   )
#   (mlp2): sep_MLP(
#     (layers): ModuleList(
#       (0-7): 8 x simple_MLP(
#         (layers): Sequential(
#           (0): Linear(in_features=64, out_features=320, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=320, out_features=1, bias=True)
#         )
#       )
#     )
#   )
#   (mlpfory): simple_MLP(
#     (layers): Sequential(
#       (0): Linear(in_features=64, out_features=1000, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=1000, out_features=4, bias=True)
#     )
#   )
#   (pt_mlp): simple_MLP(
#     (layers): Sequential(
#       (0): Linear(in_features=5248, out_features=6297, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=6297, out_features=2624, bias=True)
#     )
#   )
#   (pt_mlp2): simple_MLP(
#     (layers): Sequential(
#       (0): Linear(in_features=5248, out_features=6297, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=6297, out_features=2624, bias=True)
#     )
#   )
# )

# %%
# Start K-Fold for without pre-train
# Define the number of splits
n_splits = 4
best_valid_auroc = 0
best_valid_accuracy = 0
best_test_auroc = 0
best_test_accuracy = 0
best_valid_rmse = 100000

early_stop_counter = 0
early_stop_patience = 20

# fold_dict = {}

# Define the KFold object
kf = KFold(n_splits=n_splits, shuffle=True, random_state=21)

# Initialize lists to store the train and validation indices for each fold
train_indices_list = []
valid_indices_list = []

# Loop over the splits and get the train and validation indices for each fold
for train_indices, valid_indices in kf.split(X_train['data']):
    train_indices_list.append(train_indices)
    valid_indices_list.append(valid_indices)
best_valid_accuracy_list = []
# Loop over the folds and train the model on each fold
for fold in range(n_splits):
    # Get the train and validation indices for this fold
    train_indices = train_indices_list[fold]
    valid_indices = valid_indices_list[fold]

    # Create the train and validation datasets and dataloaders for this fold
    train_ds = DataSetCatCon(X_train, y_train, cat_idxs,opt.dtask,continuous_mean_std)
    trainloader = DataLoader(train_ds, batch_size=train_bsize,num_workers=2, sampler=torch.utils.data.SubsetRandomSampler(train_indices))
    valid_ds = DataSetCatCon(X_train, y_train, cat_idxs,opt.dtask,continuous_mean_std)
    validloader = DataLoader(valid_ds, batch_size=train_bsize, shuffle=False,num_workers=2, sampler=torch.utils.data.SubsetRandomSampler(valid_indices))
    print(f'Training begins now for # {fold} Fold.')
    # Train the model on this fold
    for epoch in range(300):
        model.train()
        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            optimizer.zero_grad()
            # x_categ is the the categorical data, with y appended as last feature. x_cont has continuous data. cat_mask is an array of ones same shape as x_categ except for last column(corresponding to y's) set to 0s. con_mask is an array of ones same shape as x_cont.
            x_categ, x_cont, y_gts, cat_mask, con_mask = data[0].to(device), data[1].to(device),data[2].to(device),data[3].to(device),data[4].to(device)
            if opt.train_noise_type is not None and opt.train_noise_level>0:
                noise_dict = {
                    'noise_type' : opt.train_noise_type,
                    'lambda' : opt.train_noise_level
                }
                if opt.train_noise_type == 'cutmix':
                    x_categ, x_cont = add_noise(x_categ,x_cont, noise_params = noise_dict)
                elif opt.train_noise_type == 'missing':
                    cat_mask, con_mask = add_noise(cat_mask, con_mask, noise_params = noise_dict)
            # We are converting the data to embeddings in the next step
            _ , x_categ_enc, x_cont_enc = embed_data_mask(x_categ, x_cont, cat_mask, con_mask,model)
            reps = model.transformer(x_categ_enc, x_cont_enc)
            # select only the representations corresponding to y and apply mlp on it in the next step to get the predictions.
            y_reps = reps[:,0,:]

            y_outs = model.mlpfory(y_reps)
            if opt.task == 'regression':
                loss = criterion(y_outs,y_gts)
            else:
                loss = criterion(y_outs,y_gts.squeeze())
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
        print(running_loss)
        if epoch%5==0:
            model.eval()
            with torch.no_grad():
                if opt.task in ['binary','multiclass']:
                    accuracy, auroc = classification_scores(model, validloader, device, opt.task)
                    # test_accuracy, test_auroc = classification_scores(model, testloader, device, opt.task)

                    print('[EPOCH %d] VALID ACCURACY: %.3f' %
                        (epoch + 1, accuracy ))
                    # print('[EPOCH %d] TEST ACCURACY: %.3f' %
                    #     (epoch + 1, test_accuracy ))

            if opt.task =='multiclass':
                if accuracy > best_valid_accuracy:
                    best_valid_accuracy = accuracy
                    early_stop_counter = 0
                    print("save model")
                    torch.save({'model': model, 'state_dict': model.state_dict(),'optimizer' : optimizer.state_dict()},modelsave_path+f"model-{fold}.pt")
                else:
                  early_stop_counter +=1
                  if early_stop_counter > early_stop_patience:
                    break


    model.eval()
    with torch.no_grad():
            accuracy, auroc = classification_scores(model, testloader, device, opt.task)
            print('TEST ACCURACY: %.3f' % accuracy)
            best_valid_accuracy_list.append(accuracy)



# End K Fold
# Calculate the average of the best accuracy from each fold
average_best_valid_accuracy = sum(best_valid_accuracy_list) / len(best_valid_accuracy_list)
print('Average best validation accuracy from all folds:', average_best_valid_accuracy)
# Out:
# Training begins now for # 0 Fold.
# 7.028339862823486
# [EPOCH 1] VALID ACCURACY: 6.000
# save model
# 6.99616265296936
# 6.988369345664978
# 7.020027160644531
# 7.047019362449646
# 6.932610750198364
# [EPOCH 6] VALID ACCURACY: 6.000
# 6.965574741363525
# 6.961134672164917
# 7.009928226470947
# 6.929276943206787
# 7.008740782737732
# [EPOCH 11] VALID ACCURACY: 6.000
# 6.945749640464783
# 7.012830018997192
# 6.946619510650635
# 6.936102867126465
# 6.939149856567383
# [EPOCH 16] VALID ACCURACY: 6.000
# 6.931910753250122
# 6.953510761260986
# 6.980416655540466
# 6.941442847251892
# 6.965010285377502
# [EPOCH 21] VALID ACCURACY: 6.000
# 6.98518431186676
# 6.999499678611755
# 6.971749424934387
# 7.000017404556274
# 6.979048371315002
# [EPOCH 26] VALID ACCURACY: 6.000
# 6.952268600463867
# 6.974586248397827
# 6.9552788734436035
# 6.983617663383484
# 6.891362428665161
# [EPOCH 31] VALID ACCURACY: 6.000
# 6.92424750328064
# 6.990475535392761
# 7.008220195770264
# 6.994825720787048
# 6.952037572860718
# [EPOCH 36] VALID ACCURACY: 6.000
# 6.886337637901306
# 6.977173686027527
# 6.933290958404541
# 6.998175501823425
# 7.017006993293762
# [EPOCH 41] VALID ACCURACY: 6.000
# 7.010694146156311
# 6.983107566833496
# 6.963582992553711
# 6.917979836463928
# 6.993439793586731
# [EPOCH 46] VALID ACCURACY: 6.000
# 6.9667205810546875
# 6.944463491439819
# 6.983353495597839
# 6.9705599546432495
# 6.960836172103882
# [EPOCH 51] VALID ACCURACY: 6.000
# 6.9830392599105835
# 7.037096738815308
# 7.0422972440719604
# 6.921254277229309
# 7.00977098941803
# [EPOCH 56] VALID ACCURACY: 6.000
# 6.957268714904785
# 6.9686092138290405
# 6.999631285667419
# 6.953903555870056
# 6.936874985694885
# [EPOCH 61] VALID ACCURACY: 6.000
# 6.967834830284119
# 7.020666837692261
# 6.942304849624634
# 6.997126579284668
# 6.956516265869141
# [EPOCH 66] VALID ACCURACY: 6.000
# 7.017147421836853
# 7.008729577064514
# 6.969709396362305
# 6.98097825050354
# 6.974137663841248
# [EPOCH 71] VALID ACCURACY: 6.000
# 7.004224896430969
# 7.013854622840881
# 6.970700263977051
# 6.98510205745697
# 6.985793948173523
# [EPOCH 76] VALID ACCURACY: 6.000
# 7.00198769569397
# 7.016453742980957
# 7.006356120109558
# 7.000730514526367
# 6.944486737251282
# [EPOCH 81] VALID ACCURACY: 6.000
# 6.991746425628662
# 7.012037754058838
# 6.997295379638672
# 7.016958594322205
# 6.943280816078186
# [EPOCH 86] VALID ACCURACY: 6.000
# 6.95941698551178
# 6.995097994804382
# 6.959354400634766
# 6.98195219039917
# 7.031785011291504
# [EPOCH 91] VALID ACCURACY: 6.000
# 7.075589537620544
# 6.976532816886902
# 6.985195636749268
# 7.009871244430542
# 6.998711466789246
# [EPOCH 96] VALID ACCURACY: 6.000
# 6.933578848838806
# 7.006039977073669
# 6.953836917877197
# 6.951675176620483
# 6.971521615982056
# [EPOCH 101] VALID ACCURACY: 6.000
# 7.009462356567383
# 7.017639398574829
# 6.952433943748474
# 6.933095455169678
# 6.9994611740112305
# [EPOCH 106] VALID ACCURACY: 6.000
# TEST ACCURACY: 9.091
# Training begins now for # 1 Fold.
# 7.069681882858276
# [EPOCH 1] VALID ACCURACY: 10.000
# save model
# 6.98006546497345
# 7.002101540565491
# 6.986698746681213
# 6.931348919868469
# 6.9729214906692505
# [EPOCH 6] VALID ACCURACY: 10.000
# 7.020817756652832
# 7.0490885972976685
# 6.930016756057739
# 6.988905906677246
# 6.973139047622681
# [EPOCH 11] VALID ACCURACY: 10.000
# 7.034167170524597
# 6.97715163230896
# 6.954456329345703
# 7.013041615486145
# 6.971057891845703
# [EPOCH 16] VALID ACCURACY: 10.000
# 6.954407811164856
# 6.94580614566803
# 6.999543905258179
# 6.925447344779968
# 6.9882025718688965
# [EPOCH 21] VALID ACCURACY: 10.000
# 7.01532518863678
# 6.974394679069519
# 6.963822364807129
# 6.974369406700134
# 6.894052147865295
# [EPOCH 26] VALID ACCURACY: 10.000
# 7.022222399711609
# 6.945584654808044
# 6.954431533813477
# 6.9493749141693115
# 6.973605275154114
# [EPOCH 31] VALID ACCURACY: 10.000
# 7.002927303314209
# 7.037738800048828
# 7.014405250549316
# 6.990627765655518
# 6.99264931678772
# [EPOCH 36] VALID ACCURACY: 10.000
# 6.998154282569885
# 6.9685609340667725
# 6.972388744354248
# 7.008971691131592
# 6.9882506132125854
# [EPOCH 41] VALID ACCURACY: 10.000
# 7.00479781627655
# 7.079470872879028
# 6.961120009422302
# 7.032558917999268
# 6.981623411178589
# [EPOCH 46] VALID ACCURACY: 10.000
# 6.970953822135925
# 7.0057090520858765
# 6.986518979072571
# 7.026387691497803
# 7.016209602355957
# [EPOCH 51] VALID ACCURACY: 10.000
# 7.023282051086426
# 6.995044469833374
# 6.92357075214386
# 6.9640525579452515
# 7.008249402046204
# [EPOCH 56] VALID ACCURACY: 10.000
# 6.967381000518799
# 7.000371694564819
# 6.9573670625686646
# 6.963706135749817
# 7.015563726425171
# [EPOCH 61] VALID ACCURACY: 10.000
# 6.962026119232178
# 6.986538052558899
# 7.056071043014526
# 6.937447786331177
# 6.970532298088074
# [EPOCH 66] VALID ACCURACY: 10.000
# 7.075560450553894
# 7.025071024894714
# 7.045198321342468
# 7.074096918106079
# 7.0178409814834595
# [EPOCH 71] VALID ACCURACY: 10.000
# 6.995516777038574
# 7.001030683517456
# 7.008484840393066
# 6.988611221313477
# 7.027181506156921
# [EPOCH 76] VALID ACCURACY: 10.000
# 7.042233943939209
# 6.982991695404053
# 6.977944731712341
# 6.945726275444031
# 6.981275200843811
# [EPOCH 81] VALID ACCURACY: 10.000
# 6.9752548933029175
# 6.961033225059509
# 6.945977210998535
# 6.9979352951049805
# 6.968417644500732
# [EPOCH 86] VALID ACCURACY: 10.000
# 6.977797985076904
# 7.00857400894165
# 6.961031079292297
# 7.02276611328125
# 7.0232648849487305
# [EPOCH 91] VALID ACCURACY: 10.000
# 6.97966992855072
# 7.057935118675232
# 6.954977631568909
# 7.002325773239136
# 6.99448037147522
# [EPOCH 96] VALID ACCURACY: 10.000
# 6.979149222373962
# 6.940136790275574
# 6.950669169425964
# 6.96820342540741
# 6.924998641014099
# [EPOCH 101] VALID ACCURACY: 10.000
# 6.9458924531936646
# 6.93218719959259
# 6.977603435516357
# 7.031632661819458
# 7.029315948486328
# [EPOCH 106] VALID ACCURACY: 10.000
# TEST ACCURACY: 9.091
# Training begins now for # 2 Fold.
# 7.007952451705933
# [EPOCH 1] VALID ACCURACY: 10.204
# save model
# 7.014464497566223
# 6.98282527923584
# 7.0489197969436646
# 7.016629695892334
# 6.996639847755432
# [EPOCH 6] VALID ACCURACY: 10.204
# 6.987886428833008
# 7.024638652801514
# 7.005638599395752
# 6.930618762969971
# 6.978775978088379
# [EPOCH 11] VALID ACCURACY: 10.204
# 7.038654446601868
# 7.043162822723389
# 7.01496946811676
# 7.020494341850281
# 7.009782910346985
# [EPOCH 16] VALID ACCURACY: 10.204
# 6.983160972595215
# 6.995523691177368
# 7.0370248556137085
# 6.949231147766113
# 7.03477144241333
# [EPOCH 21] VALID ACCURACY: 10.204
# 7.0180500745773315
# 7.0337042808532715
# 6.997342109680176
# 7.005910038948059
# 7.04613721370697
# [EPOCH 26] VALID ACCURACY: 10.204
# 7.009186387062073
# 6.997444748878479
# 6.953825950622559
# 6.86024272441864
# 6.949151277542114
# [EPOCH 31] VALID ACCURACY: 10.204
# 7.053527474403381
# 7.070900797843933
# 7.0592522621154785
# 7.014520168304443
# 6.9632850885391235
# [EPOCH 36] VALID ACCURACY: 10.204
# 7.018643260002136
# 6.989448428153992
# 7.0207600593566895
# 7.030060768127441
# 6.9790849685668945
# [EPOCH 41] VALID ACCURACY: 10.204
# 6.981213927268982
# 7.066125512123108
# 6.94613778591156
# 7.0296103954315186
# 6.946530342102051
# [EPOCH 46] VALID ACCURACY: 10.204
# 6.94481348991394
# 6.98791241645813
# 7.0068039894104
# 7.016480088233948
# 6.976671576499939
# [EPOCH 51] VALID ACCURACY: 10.204
# 7.048424959182739
# 6.991990447044373
# 7.0560725927352905
# 7.007945537567139
# 6.94624662399292
# [EPOCH 56] VALID ACCURACY: 10.204
# 6.984914779663086
# 6.9687711000442505
# 7.047008991241455
# 7.003902196884155
# 6.997425079345703
# [EPOCH 61] VALID ACCURACY: 10.204
# 6.92063844203949
# 6.9443559646606445
# 6.939988970756531
# 7.020774483680725
# 7.004009366035461
# [EPOCH 66] VALID ACCURACY: 10.204
# 6.996734142303467
# 6.9957804679870605
# 7.063049554824829
# 7.011397838592529
# 7.046101450920105
# [EPOCH 71] VALID ACCURACY: 10.204
# 6.922476410865784
# 7.013863205909729
# 7.0411616563797
# 6.966553688049316
# 6.963719606399536
# [EPOCH 76] VALID ACCURACY: 10.204
# 6.926853060722351
# 6.993496417999268
# 7.029372453689575
# 6.987858414649963
# 7.004117488861084
# [EPOCH 81] VALID ACCURACY: 10.204
# 6.981661915779114
# 7.038668751716614
# 6.946025967597961
# 6.993274450302124
# 6.969174385070801
# [EPOCH 86] VALID ACCURACY: 10.204
# 6.988776206970215
# 7.009418606758118
# 6.986911416053772
# 6.96176540851593
# 6.994148135185242
# [EPOCH 91] VALID ACCURACY: 10.204
# 6.986797213554382
# 6.999519348144531
# 7.012009382247925
# 7.019931197166443
# 6.957974195480347
# [EPOCH 96] VALID ACCURACY: 10.204
# 6.976463675498962
# 6.955415487289429
# 7.010689854621887
# 7.010960936546326
# 6.986104607582092
# [EPOCH 101] VALID ACCURACY: 10.204
# 6.930290341377258
# 7.024828195571899
# 7.010678768157959
# 6.999778985977173
# 7.002955436706543
# [EPOCH 106] VALID ACCURACY: 10.204
# TEST ACCURACY: 9.091
# Training begins now for # 3 Fold.
# 6.988157749176025
# [EPOCH 1] VALID ACCURACY: 16.327
# save model
# 7.065843820571899
# 6.980266094207764
# 6.986114978790283
# 7.073510527610779
# 7.013175964355469
# [EPOCH 6] VALID ACCURACY: 16.327
# 7.028161525726318
# 7.099369406700134
# 7.06458580493927
# 7.087228417396545
# 7.072814106941223
# [EPOCH 11] VALID ACCURACY: 16.327
# 7.016535043716431
# 7.074220061302185
# 7.0864598751068115
# 7.079916954040527
# 7.029962778091431
# [EPOCH 16] VALID ACCURACY: 16.327
# 7.009851574897766
# 7.021971106529236
# 7.026493310928345
# 7.02155613899231
# 7.036892414093018
# [EPOCH 21] VALID ACCURACY: 16.327
# 7.103562831878662
# 7.049577713012695
# 7.060377359390259
# 6.988787651062012
# 7.060979604721069
# [EPOCH 26] VALID ACCURACY: 16.327
# 7.102002501487732
# 7.038464069366455
# 7.021312117576599
# 7.008727788925171
# 7.038245677947998
# [EPOCH 31] VALID ACCURACY: 16.327
# 7.000628232955933
# 7.015184998512268
# 6.961472153663635
# 7.032747507095337
# 7.071202874183655
# [EPOCH 36] VALID ACCURACY: 16.327
# 7.0276453495025635
# 7.082415580749512
# 7.015284299850464
# 7.080532908439636
# 7.022029757499695
# [EPOCH 41] VALID ACCURACY: 16.327
# 7.109492778778076
# 7.03349506855011
# 7.073606729507446
# 7.113077402114868
# 7.0425567626953125
# [EPOCH 46] VALID ACCURACY: 16.327
# 7.023050308227539
# 7.013102650642395
# 7.063273906707764
# 6.992453098297119
# 7.003693580627441
# [EPOCH 51] VALID ACCURACY: 16.327
# 7.072435736656189
# 7.096047759056091
# 7.021291732788086
# 7.006799101829529
# 6.98895788192749
# [EPOCH 56] VALID ACCURACY: 16.327
# 7.050440073013306
# 7.03198766708374
# 7.020602107048035
# 7.018874764442444
# 7.049767017364502
# [EPOCH 61] VALID ACCURACY: 16.327
# 7.035431861877441
# 7.04042911529541
# 7.016773700714111
# 7.038236618041992
# 7.041828632354736
# [EPOCH 66] VALID ACCURACY: 16.327
# 6.9982346296310425
# 6.991279721260071
# 7.059474349021912
# 7.034610867500305
# 7.0275774002075195
# [EPOCH 71] VALID ACCURACY: 16.327
# 7.023896932601929
# 6.9852166175842285
# 6.962725639343262
# 7.090082883834839
# 7.08449387550354
# [EPOCH 76] VALID ACCURACY: 16.327
# 7.064731955528259
# 7.063694357872009
# 7.061461567878723
# 7.105122685432434
# 7.0342676639556885
# [EPOCH 81] VALID ACCURACY: 16.327
# 7.041444897651672
# 7.0948039293289185
# 7.03239643573761
# 7.024456262588501
# 7.1165931224823
# [EPOCH 86] VALID ACCURACY: 16.327
# 7.068795800209045
# 7.097066879272461
# 7.013011455535889
# 7.1027127504348755
# 7.014776825904846
# [EPOCH 91] VALID ACCURACY: 16.327
# 7.005000829696655
# 7.065528631210327
# 7.088801860809326
# 7.048061966896057
# 6.978009581565857
# [EPOCH 96] VALID ACCURACY: 16.327
# 7.082104921340942
# 7.0127551555633545
# 7.078073263168335
# 6.973707318305969
# 7.006655693054199
# [EPOCH 101] VALID ACCURACY: 16.327
# 6.982818007469177
# 7.038772225379944
# 7.041889905929565
# 7.056207060813904
# 7.06824803352356
# [EPOCH 106] VALID ACCURACY: 16.327
# TEST ACCURACY: 9.091
# Average best validation accuracy from all folds: 9.090909004211426

# %%
best_valid_accuracy_list
# Out:
# [array(9.090909, dtype=float32),
#  array(9.090909, dtype=float32),
#  array(9.090909, dtype=float32),
#  array(9.090909, dtype=float32)]
